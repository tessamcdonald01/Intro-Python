# %%
import pandas as pd

data = pd.read_csv('Table1_SurfaceAgesAndErosion_Balter_Kennedy2021_JakobshavnErosion.csv')


data.head()
# Out:
#   Table 1 - Exposure ages and erosion rates from surficial bedrock samples at Jakobshavn Isbræ.  \
# 0                                 Number in Figure 1
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3                         Unnamed: 4  \
# 0  Sample ID     Group*   Location  Historical Cover Duration (years)
# 1  JAKN08-56   Outboard      North                                  -
# 2  JAKN08-44   Outboard      North                                  -
# 3  JAKN08-28   Outboard      North                                  -
# 4  JAKN08-39   Outboard      North                                  -
#
#                                          Unnamed: 5           Unnamed: 6  \
# 0  Uncertainty in Historical Cover Duration (years)  Lm Age (years ± SD)
# ...

# %%
data.columns =data.iloc[0]

data.drop(
    labels=[0],
    axis = 0,
    inplace = True
)

# %%
data.head()
# Out:
# 0 Number in Figure 1  Sample ID    Group* Location  \
# 1                  1  JAKN08-56  Outboard    North
# 2                  2  JAKN08-44  Outboard    North
# 3                  3  JAKN08-28  Outboard    North
# 4                  4  JAKN08-39  Outboard    North
# 5                  5  JAKN08-40  Outboard    North
#
# 0 Historical Cover Duration (years)  \
# 1                                 -
# 2                                 -
# 3                                 -
# 4                                 -
# 5                                 -
#
# 0 Uncertainty in Historical Cover Duration (years) Lm Age (years ± SD)  \
# 1                                                -                7480
# 2                                                -                7350
# 3                                                -                7410
# 4                                                -                7430
# 5                                                -                7890
#
# ...
